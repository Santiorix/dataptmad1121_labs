# %% [markdown]
# # Before your start:
# - Read the README.md file
# - Comment as much as you can and use the resources in the README.md file
# - Happy learning!

# %%
# Import reduce from functools, numpy and pandas
import functools
import numpy as np
import pandas as pd
import re

# %% [markdown]
# # Challenge 1 - Mapping
#
# #### We will use the map function to clean up words in a book.
#
# In the following cell, we will read a text file containing the book The Prophet by Khalil Gibran.

# %%
# Run this code:

location = '../data/58585-0.txt'
with open(location, 'r', encoding="utf8") as f:
    prophet = f.read().split(' ')
#print (prophet)

# %% [markdown]
# #### Let's remove the first 568 words since they contain information about the book but are not part of the book itself.
#
# Do this by removing from `prophet` elements 0 through 567 of the list (you can also do this by keeping elements 568 through the last element).

# %%
# your code here
prophet = prophet[568:]
prophet
# Out:
# ['PROPHET\n\n|Almustafa,',
#  'the{7}',
#  'chosen',
#  'and',
#  'the\nbeloved,',
#  'who',
#  'was',
#  'a',
#  'dawn',
#  'unto',
#  'his',
#  'own\nday,',
#  'had',
#  'waited',
#  'twelve',
#  'years',
#  'in',
#  'the',
#  'city\nof',
#  'Orphalese',
#  'for',
#  'his',
#  'ship',
#  'that',
#  'was',
#  'to\nreturn',
#  'and',
#  'bear',
#  'him',
#  'back',
#  'to',
#  'the',
#  'isle',
#  'of\nhis',
#  'birth.\n\nAnd',
#  'in',
#  'the',
#  'twelfth',
#  'year,',
#  'on',
#  'the',
#  'seventh\nday',
#  'of',
#  'Ielool,',
#  'the',
#  'month',
#  'of',
#  'reaping,',
#  'he\nclimbed',
#  'the',
#  'hill',
#  'without',
#  'the',
#  'city',
#  'walls\nand',
#  'looked',
#  'seaward;',
#  'and',
#  'he',
#  'beheld',
#  'his\nship',
#  'coming',
#  'with',
#  'the',
#  'mist.\n\nThen',
#  'the',
#  'gates',
#  'of',
#  'his',
#  'heart',
#  'were',
#  'flung\nopen,',
#  'and',
#  'his',
#  'joy',
#  'flew',
#  'far',
#  'over',
#  'the',
#  'sea.\nAnd',
#  'he',
#  'closed',
# ...

# %% [markdown]
# If you look through the words, you will find that many words have a reference attached to them. For example, let's look at words 1 through 10.

# %%
# your code here
book_1_10 = prophet[:10]
print(book_1_10)
# Out:
# ['PROPHET\n\n|Almustafa,', 'the{7}', 'chosen', 'and', 'the\nbeloved,', 'who', 'was', 'a', 'dawn', 'unto']

# %% [markdown]
# #### The next step is to create a function that will remove references.
#
# We will do this by splitting the string on the `{` character and keeping only the part before this character. Write your function below.

# %%
def reference(x):
       #for i in x:
        c = x.split("{")
        lst = c[0]
        print(lst)

    # your code here

# %%
def reference(x):
    c= " ".join(x)
    return c.split("{")[0]

# %%
reference(book_1_10)
# Out:
# 'PROPHET\n\n|Almustafa, the'

# %%
reference(prophet)
# Out:
# 'PROPHET\n\n|Almustafa, the'

# %%
#book_1_10[1].split("{")
#list2 = [i[0] for i in book_1_10 i.split("{")]
#print(list2)

# %%
#for i in book_1_10:
   #c = i.split("{")
    #lst = c[0]
    #print(lst)

# %% [markdown]
# Now that we have our function, use the `map()` function to apply this function to our book, The Prophet. Return the resulting list to a new list called `prophet_reference`.

# %%
# your code here
#map (reference, prophet)
prophet_reference = list(map(reference, prophet))
print (prophet_reference) #no sé por que me sale así y por que no me salta el 7, cuando en la función reference si que lo hace
# Out:
# ['P R O P H E T \n \n | A l m u s t a f a ,', 't h e ', 'c h o s e n', 'a n d', 't h e \n b e l o v e d ,', 'w h o', 'w a s', 'a', 'd a w n', 'u n t o', 'h i s', 'o w n \n d a y ,', 'h a d', 'w a i t e d', 't w e l v e', 'y e a r s', 'i n', 't h e', 'c i t y \n o f', 'O r p h a l e s e', 'f o r', 'h i s', 's h i p', 't h a t', 'w a s', 't o \n r e t u r n', 'a n d', 'b e a r', 'h i m', 'b a c k', 't o', 't h e', 'i s l e', 'o f \n h i s', 'b i r t h . \n \n A n d', 'i n', 't h e', 't w e l f t h', 'y e a r ,', 'o n', 't h e', 's e v e n t h \n d a y', 'o f', 'I e l o o l ,', 't h e', 'm o n t h', 'o f', 'r e a p i n g ,', 'h e \n c l i m b e d', 't h e', 'h i l l', 'w i t h o u t', 't h e', 'c i t y', 'w a l l s \n a n d', 'l o o k e d', 's e a w a r d ;', 'a n d', 'h e', 'b e h e l d', 'h i s \n s h i p', 'c o m i n g', 'w i t h', 't h e', 'm i s t . \n \n T h e n', 't h e', 'g a t e s', 'o f', 'h i s', 'h e a r t', 'w e r e', 'f l u n g \n o p e n ,', 'a n d', 'h i s', 'j o y', 'f 
# ...

# %% [markdown]
# Another thing you may have noticed is that some words contain a line break. Let's write a function to split those words. Our function will return the string split on the character `\n`. Write your function in the cell below.

# %%
def line_break(x):
    b = x.split('\n')
    return (b)

# %%
line_break('t h e \n b e l o v e d ,')
# Out:
# ['t h e ', ' b e l o v e d ,']

# %% [markdown]
# Apply the `line_break` function to the `prophet_reference` list. Name the new list `prophet_line`.

# %%
# your code here
prophet_line = list(map(line_break, prophet_reference))
prophet_line
# Out:
# [['P R O P H E T ', ' ', ' | A l m u s t a f a ,'],
#  ['t h e '],
#  ['c h o s e n'],
#  ['a n d'],
#  ['t h e ', ' b e l o v e d ,'],
#  ['w h o'],
#  ['w a s'],
#  ['a'],
#  ['d a w n'],
#  ['u n t o'],
#  ['h i s'],
#  ['o w n ', ' d a y ,'],
#  ['h a d'],
#  ['w a i t e d'],
#  ['t w e l v e'],
#  ['y e a r s'],
#  ['i n'],
#  ['t h e'],
#  ['c i t y ', ' o f'],
#  ['O r p h a l e s e'],
#  ['f o r'],
#  ['h i s'],
#  ['s h i p'],
#  ['t h a t'],
#  ['w a s'],
#  ['t o ', ' r e t u r n'],
#  ['a n d'],
#  ['b e a r'],
#  ['h i m'],
#  ['b a c k'],
#  ['t o'],
#  ['t h e'],
#  ['i s l e'],
#  ['o f ', ' h i s'],
#  ['b i r t h . ', ' ', ' A n d'],
#  ['i n'],
#  ['t h e'],
#  ['t w e l f t h'],
#  ['y e a r ,'],
#  ['o n'],
#  ['t h e'],
#  ['s e v e n t h ', ' d a y'],
#  ['o f'],
#  ['I e l o o l ,'],
#  ['t h e'],
#  ['m o n t h'],
#  ['o f'],
#  ['r e a p i n g ,'],
#  ['h e ', ' c l i m b e d'],
#  ['t h e'],
#  ['h i l l'],
#  ['w i t h o u t'],
#  ['t h e'],
# ...

# %% [markdown]
# If you look at the elements of `prophet_line`, you will see that the function returned lists and not strings. Our list is now a list of lists. Flatten the list using list comprehension. Assign this new list to `prophet_flat`.

# %%
# your code here
prophet_flat = [' '.join(i) for i in prophet_line]
prophet_flat
# Out:
# ['P R O P H E T     | A l m u s t a f a ,',
#  't h e ',
#  'c h o s e n',
#  'a n d',
#  't h e   b e l o v e d ,',
#  'w h o',
#  'w a s',
#  'a',
#  'd a w n',
#  'u n t o',
#  'h i s',
#  'o w n   d a y ,',
#  'h a d',
#  'w a i t e d',
#  't w e l v e',
#  'y e a r s',
#  'i n',
#  't h e',
#  'c i t y   o f',
#  'O r p h a l e s e',
#  'f o r',
#  'h i s',
#  's h i p',
#  't h a t',
#  'w a s',
#  't o   r e t u r n',
#  'a n d',
#  'b e a r',
#  'h i m',
#  'b a c k',
#  't o',
#  't h e',
#  'i s l e',
#  'o f   h i s',
#  'b i r t h .     A n d',
#  'i n',
#  't h e',
#  't w e l f t h',
#  'y e a r ,',
#  'o n',
#  't h e',
#  's e v e n t h   d a y',
#  'o f',
#  'I e l o o l ,',
#  't h e',
#  'm o n t h',
#  'o f',
#  'r e a p i n g ,',
#  'h e   c l i m b e d',
#  't h e',
#  'h i l l',
#  'w i t h o u t',
#  't h e',
#  'c i t y',
#  'w a l l s   a n d',
#  'l o o k e d',
#  's e a w a r d ;',
#  'a n d',
#  'h e',
#  'b e h e l d',
#  'h i s   s h i p',
# ...

# %% [markdown]
# # Challenge 2 - Filtering
#
# When printing out a few words from the book, we see that there are words that we may not want to keep if we choose to analyze the corpus of text. Below is a list of words that we would like to get rid of. Create a function that will return false if it contains a word from the list of words specified and true otherwise.

# %%
def word_filter(x):
    '''
    Input: A string
    Output: True if the word is not in the specified list 
    and False if the word is in the list.
        
    Example:
    word list = ['and', 'the']
    Input: 'and'
    Output: False
    
    Input: 'John'
    Output: True
    '''
    word_list = ['and', 'the', 'a', 'an']
    if x in word_list:
        return False
    else:
        return True
    # your code here
word_filter("otros")
# Out:
# True

# %% [markdown]
# Use the `filter()` function to filter out the words speficied in the `word_filter()` function. Store the filtered list in the variable `prophet_filter`.

# %%
filter(word_filter, prophet_flat)
prophet_filter = list(filter(word_filter, prophet_flat)) #No entiendo por que no funciona, la función funciona y la forma de hacerlo es así
prophet_filter
# Out:
# ['P R O P H E T     | A l m u s t a f a ,',
#  't h e ',
#  'c h o s e n',
#  'a n d',
#  't h e   b e l o v e d ,',
#  'w h o',
#  'w a s',
#  'd a w n',
#  'u n t o',
#  'h i s',
#  'o w n   d a y ,',
#  'h a d',
#  'w a i t e d',
#  't w e l v e',
#  'y e a r s',
#  'i n',
#  't h e',
#  'c i t y   o f',
#  'O r p h a l e s e',
#  'f o r',
#  'h i s',
#  's h i p',
#  't h a t',
#  'w a s',
#  't o   r e t u r n',
#  'a n d',
#  'b e a r',
#  'h i m',
#  'b a c k',
#  't o',
#  't h e',
#  'i s l e',
#  'o f   h i s',
#  'b i r t h .     A n d',
#  'i n',
#  't h e',
#  't w e l f t h',
#  'y e a r ,',
#  'o n',
#  't h e',
#  's e v e n t h   d a y',
#  'o f',
#  'I e l o o l ,',
#  't h e',
#  'm o n t h',
#  'o f',
#  'r e a p i n g ,',
#  'h e   c l i m b e d',
#  't h e',
#  'h i l l',
#  'w i t h o u t',
#  't h e',
#  'c i t y',
#  'w a l l s   a n d',
#  'l o o k e d',
#  's e a w a r d ;',
#  'a n d',
#  'h e',
#  'b e h e l d',
#  'h i s   s h i p',
#  'c o m i n g',
# ...

# %% [markdown]
# # Bonus Challenge
#
# Rewrite the `word_filter` function above to not be case sensitive.

# %%
def word_filter_case(x):
    word_list = ['and', 'the', 'a', 'an']
    if x.lower() in word_list:
        return False
    else:
        return True

# %%
word_filter_case("And")
# Out:
# False

# %% [markdown]
# # Challenge 3 - Reducing
#
# #### Now that we have significantly cleaned up our text corpus, let's use the `reduce()` function to put the words back together into one long string separated by spaces.
#
# We will start by writing a function that takes two strings and concatenates them together with a space between the two strings.

# %%
def concat_space(a, b):
    '''
    Input:Two strings
    Output: A single string separated by a space
        
    Example:
    Input: 'John', 'Smith'
    Output: 'John Smith'
    '''
    
    # your code here
    z = [a,b]
    d = ' '.join(z)
    return (d)

# %%
concat_space('John', 'Smith')
# Out:
# 'John Smith'

# %% [markdown]
# Use the function above to reduce the text corpus in the list `prophet_filter` into a single string. Assign this new string to the variable `prophet_string`.

# %%
from functools import reduce
prophet_string = reduce(concat_space, prophet_filter)
prophet_string
# Out:
# 'P R O P H E T     | A l m u s t a f a , t h e  c h o s e n a n d t h e   b e l o v e d , w h o w a s d a w n u n t o h i s o w n   d a y , h a d w a i t e d t w e l v e y e a r s i n t h e c i t y   o f O r p h a l e s e f o r h i s s h i p t h a t w a s t o   r e t u r n a n d b e a r h i m b a c k t o t h e i s l e o f   h i s b i r t h .     A n d i n t h e t w e l f t h y e a r , o n t h e s e v e n t h   d a y o f I e l o o l , t h e m o n t h o f r e a p i n g , h e   c l i m b e d t h e h i l l w i t h o u t t h e c i t y w a l l s   a n d l o o k e d s e a w a r d ; a n d h e b e h e l d h i s   s h i p c o m i n g w i t h t h e m i s t .     T h e n t h e g a t e s o f h i s h e a r t w e r e f l u n g   o p e n , a n d h i s j o y f l e w f a r o v e r t h e s e a .   A n d h e c l o s e d h i s e y e s a n d p r a y e d i n t h e   s i l e n c e s o f h i s s o u l .     * * * * *     B u t a s h e d e s c e n d e d t h e h i l l , s a d n e s s   c a m e u p o n h i m , 
# ...

# %% [markdown]
# # Challenge 4 - Applying Functions to DataFrames
#
# #### Our next step is to use the apply function to a dataframe and transform all cells.
#
# To do this, we will connect to Ironhack's database and retrieve the data from the *pollution* database. Select the *beijing_pollution* table and retrieve its data.

# %%
# your code here
data = pd.read_csv('C:/Users/34699/Desktop/Ironhack/beijing_pollution.csv')

# %% [markdown]
# Let's look at the data using the `head()` function.

# %%
# your code here
data.head()
# Out:
#    No  year  month  day  hour  pm2.5  DEWP  TEMP    PRES cbwd    Iws  Is  Ir
# 0   1  2010      1    1     0    NaN   -21 -11.0  1021.0   NW   1.79   0   0
# 1   2  2010      1    1     1    NaN   -21 -12.0  1020.0   NW   4.92   0   0
# 2   3  2010      1    1     2    NaN   -21 -11.0  1019.0   NW   6.71   0   0
# 3   4  2010      1    1     3    NaN   -21 -14.0  1019.0   NW   9.84   0   0
# 4   5  2010      1    1     4    NaN   -20 -12.0  1018.0   NW  12.97   0   0

# %% [markdown]
# The next step is to create a function that divides a cell by 24 to produce an hourly figure. Write the function below.

# %%
def hourly(x):
    '''
    Input: A numerical value
    Output: The value divided by 24
        
    Example:
    Input: 48
    Output: 2.0
    '''
    return (x/24)
    # your code here
hourly(48)
# Out:
# 2.0

# %% [markdown]
# Apply this function to the columns `Iws`, `Is`, and `Ir`. Store this new dataframe in the variable `pm25_hourly`.

# %%
pm25_hourly = data [['Iws', 'Is', 'Ir']].apply(hourly)
pm25_hourly.head()
#pm25_hourly['Is'] = data['Is'].apply(hourly)
#pd.DataFrame(pm25_hourly)
#pm25_hourly['Ir'] = data['Ir'].apply(hourly)
#pd.DataFrame(pm25_hourly)
#pm25_hourly.head()
#type(pm25_hourly)
# Out:
#         Iws   Is   Ir
# 0  0.074583  0.0  0.0
# 1  0.205000  0.0  0.0
# 2  0.279583  0.0  0.0
# 3  0.410000  0.0  0.0
# 4  0.540417  0.0  0.0

# %% [markdown]
# #### Our last challenge will be to create an aggregate function and apply it to a select group of columns in our dataframe.
#
# Write a function that returns the standard deviation of a column divided by the length of a column minus 1. Since we are using pandas, do not use the `len()` function. One alternative is to use `count()`. Also, use the numpy version of standard deviation.

# %%
pd_serie = pd.Series([2,2,2,4])
#print(pd_serie.count()-1)
def sample_sd(x):
    '''
    Input: A Pandas series of values
    Output: the standard deviation divided by the number of elements in the series
        
    Example:
    Input: pd.Series([1,2,3,4])
    Output: 0.3726779962    '''
    # your code here
    print(np.std(x)/(x.count()-1))
sample_sd(pd_serie)
# Out:
# 0.28867513459481287

# %% [markdown]
# ### Lo voy a aplicar a las columnas que quiera por que no veo una indicación clara respecto a esto

# %%
data[['PRES', 'Iws']].apply(sample_sd)
# Out:
# 0.0002343194396212868
# 0.00114118303349757
# PRES    None
# Iws     None
# dtype: object
